# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
interval = 50
folder = './Drive/record/'
colors = sns.color_palette("hls", 8)

f0 = '0.70_0.99_normal_steps'
df0 = pd.read_csv(folder+f0+'.csv')
df0.columns = [f0]
f1 = '0.7_0.99_human_steps'
df1 = pd.read_csv(folder+f1+'.csv')
df1.columns = [f1]
f2 = '0.70_0.99_n_ethical_steps'
df2 = pd.read_csv(folder+f2+'.csv')
df2.columns = [f2]

df = pd.concat([df0, df1, df2], axis=1)
mean = df.rolling(interval).mean()
mean.plot()

plt.plot()
# Out:
# []

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
interval = 50
folder = './Drive/record/'
colors = sns.color_palette("hls", 8)

f0 = '2.00_0.20_normal_cat_hits'
df0 = pd.read_csv(folder+f0+'.csv')
df0.columns = [f0]
f1 = '2_0.2_human_cat_hits'
df1 = pd.read_csv(folder+f1+'.csv')
df1.columns = [f1]
f2 = '1.00_0.10_n_ethical_cat_hits'
df2 = pd.read_csv(folder+f2+'.csv')
df2.columns = [f2]

df = pd.concat([df0, df1, df2], axis=1)
mean = df.rolling(interval).mean()
mean.plot()


plt.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-205-768f355b06ee> in <module>()
#      13 df1.columns = [f1]
#      14 f2 = '1.00_0.10_n_ethical_cat_hits'
# ---> 15 df2 = pd.read_csv(folder+f2+'.csv')
#      16 df2.columns = [f2]
#      17
#
# ~/Denv/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# ~/Denv/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# ~/Denv/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# ~/Denv/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# ~/Denv/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'./Drive/record/1.00_0.10_n_ethical_cat_hits.csv' does not exist

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
interval = 20
folder = './Drive/record/'
colors = sns.color_palette("hls", 8)

f0 = '2.00_0.80_normal_collisions'
df0 = pd.read_csv(folder+f0+'.csv')
df0.columns = [f0]
f1 = '2_0.55_human_collisions'
df1 = pd.read_csv(folder+f1+'.csv')
df1.columns = [f1]
f2 = '2.00_0.80_n_ethical_collisions'
df2 = pd.read_csv(folder+f2+'.csv')
df2.columns = [f2]

df = pd.concat([df0, df1, df2], axis=1)
mean = df.rolling(interval).mean()
mean.plot()


plt.plot()
# Out:
# []
