# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
interval = 30
folder = './record/'
colors = sns.color_palette("hls", 8)

df0 = pd.read_csv(folder+'2.0_0.55_normal_pos_passed.csv')
df0.columns = ['normal']
df1 = pd.read_csv(folder+'2.0_0.55_ethical_pos_passed.csv')
df1.columns = ['ethical']
mean = df.rolling(interval).mean()
df = pd.concat([df0, df1], axis=1)
#sns.tsplot(np.transpose(mean['normal'].values), color=colors[0])
#sns.tsplot(np.transpose(mean['ethical'].values), color=colors[1])

mean.plot()
plt.plot()
# Out:
# []

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
interval = 30
folder = './record/'
colors = sns.color_palette("hls", 8)

df0 = pd.read_csv(folder+'1.5_0.2_normal_neg_passed.csv')
df0.columns = ['normal']
df1 = pd.read_csv(folder+'2.0_0.2_ethical_neg_passed.csv')
df1.columns = ['ethical']
mean = df.rolling(interval).mean()
df = pd.concat([df0, df1], axis=1)
#sns.tsplot(np.transpose(mean['normal'].values), color=colors[0])
#sns.tsplot(np.transpose(mean['ethical'].values), color=colors[1])

mean.plot()
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-84-f89ea69fe825> in <module>()
#       8 df0 = pd.read_csv(folder+'1.5_0.2_normal_neg_passed.csv')
#       9 df0.columns = ['normal']
# ---> 10 df1 = pd.read_csv(folder+'2.0_0.2_ethical_neg_passed.csv')
#      11 df1.columns = ['ethical']
#      12 mean = df.rolling(interval).mean()
#
# ...

# %%
df0 = pd.read_csv(folder+'ethical_steps.csv')
df1 = pd.read_csv(folder+'normal_steps.csv')
df = pd.concat([df0, df1], axis=1)
mean = df.rolling(interval).mean()


mean.plot()
plt.plot()
# Out:
# []
